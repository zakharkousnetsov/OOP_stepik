# %% [markdown]
# # Подвиг 2.

# %% [markdown]
# Объявите класс Money так, чтобы объекты этого класса можно было создавать следующим образом:
#
# my_money = Money(100)
# your_money = Money(1000)
# Здесь при создании объектов указывается количество денег, которое должно сохраняться в локальном свойстве (атрибуте) money каждого экземпляра класса.
#
# P.S. На экран в программе ничего выводить не нужно.

# %%
# здесь объявляйте класс Money
class Money():
    def __init__(self, money):
        self.money  = money 

my_money = Money(100)
your_money = Money(1000)

# %% [markdown]
# # Подвиг 3.

# %% [markdown]
# Объявите класс Point так, чтобы объекты этого класса можно было создавать командами:
#
# p1 = Point(10, 20)
# p2 = Point(12, 5, 'red')
# Здесь первые два значения - это координаты точки на плоскости (локальные свойства x, y), а третий необязательный аргумент - цвет точки (локальное свойство color). Если цвет не указывается, то он по умолчанию принимает значение black.
#
# Создайте тысячу таких объектов с координатами (1, 1), (3, 3), (5, 5), ... то есть, с увеличением на два для каждой новой точки. Каждый объект следует поместить в список points (по порядку). Для второго объекта в списке points укажите цвет 'yellow'.
#
# P.S. На экран в программе ничего выводить не нужно.

# %%
class Point():
    def __init__(self, x, y, color='black'):
        self.x = x
        self.y = y
        self.color=color

points  = []
i = 1
while len(points)<1000:
    pt = Point(i, i)
    if len(points) == 1:
        pt = Point(i, i, 'yellow')
    points.append(pt)
    i += 2

points
# Out:
# [<__main__.Point at 0x7d2a07f442b0>,
#  <__main__.Point at 0x7d2a07f47040>,
#  <__main__.Point at 0x7d2a07f44520>,
#  <__main__.Point at 0x7d2a07f45990>,
#  <__main__.Point at 0x7d2a07f458d0>,
#  <__main__.Point at 0x7d2a07f45900>,
#  <__main__.Point at 0x7d2a07f47760>,
#  <__main__.Point at 0x7d2a07f44490>,
#  <__main__.Point at 0x7d2a07f444c0>,
#  <__main__.Point at 0x7d2a07f45330>,
#  <__main__.Point at 0x7d2a07f44cd0>,
#  <__main__.Point at 0x7d2a07f450c0>,
#  <__main__.Point at 0x7d2a07f44160>,
#  <__main__.Point at 0x7d2a07f44910>,
#  <__main__.Point at 0x7d2a07f44940>,
#  <__main__.Point at 0x7d2a07f44970>,
#  <__main__.Point at 0x7d2a07f461d0>,
#  <__main__.Point at 0x7d2a07f46230>,
#  <__main__.Point at 0x7d2a07f44c70>,
#  <__main__.Point at 0x7d2a07f45b70>,
#  <__main__.Point at 0x7d2a07f457b0>,
#  <__main__.Point at 0x7d2a07f457e0>,
#  <__main__.Point at 0x7d2a07f45390>,
#  <__main__.Point at 0x7d2a07f45360>,
#  <__main__.Point at 0x7d2a07f452a0>,
#  <__main__.Point at 0x7d2a07f44d90>,
#  <__main__.Point at 0x7d2a07f46d10>,
#  <__main__.Point at 0x7d2a07f45810>,
#  <__main__.Point at 0x7d2a07f44550>,
#  <__main__.Point at 0x7d2a07f44d30>,
#  <__main__.Point at 0x7d2a07f46110>,
#  <__main__.Point at 0x7d2a07f461a0>,
#  <__main__.Point at 0x7d2a07f45780>,
#  <__main__.Point at 0x7d2a07f44a30>,
#  <__main__.Point at 0x7d2a07f44370>,
#  <__main__.Point at 0x7d2a07f458a0>,
#  <__main__.Point at 0x7d2a07f45a20>,
#  <__main__.Point at 0x7d2a07f45ae0>,
#  <__main__.Point at 0x7d2a07f44400>,
#  <__main__.Point at 0x7d2a07f45840>,
#  <__main__.Point at 0x7d2a07f45570>,
#  <__main__.Point at 0x7d2a07f45e40>,
#  <__main__.Point at 0x7d2a07f47880>,
#  <__main__.Point at 0x7d2a07f47fd0>,
#  <__main__.Point at 0x7d2a07f46350>,
#  <__main__.Point at 0x7d2a07f463b0>,
#  <__main__.Point at 0x7d2a07f46410>,
#  <__main__.Point at 0x7d2a07f46470>,
#  <__main__.Point at 0x7d2a07f464d0>,
#  <__main__.Point at 0x7d2a07f46530>,
#  <__main__.Point at 0x7d2a07f46590>,
#  <__main__.Point at 0x7d2a07f465f0>,
#  <__main__.Point at 0x7d2a07f46650>,
#  <__main__.Point at 0x7d2a07f466b0>,
#  <__main__.Point at 0x7d2a07f46710>,
#  <__main__.Point at 0x7d2a07f46770>,
#  <__main__.Point at 0x7d2a07f467d0>,
#  <__main__.Point at 0x7d2a07f46830>,
#  <__main__.Point at 0x7d2a07f46890>,
#  <__main__.Point at 0x7d2a07f468f0>,
#  <__main__.Point at 0x7d2a07f46950>,
#  <__main__.Point at 0x7d2a07f469b0>,
#  <__main__.Point at 0x7d2a07f46a10>,
#  <__main__.Point at 0x7d2a07f47e80>,
#  <__main__.Point at 0x7d2a07f47e20>,
#  <__main__.Point at 0x7d2a07f47dc0>,
#  <__main__.Point at 0x7d2a07f47d60>,
#  <__main__.Point at 0x7d2a07f47d00>,
#  <__main__.Point at 0x7d2a07f47ca0>,
#  <__main__.Point at 0x7d2a07f47c40>,
#  <__main__.Point at 0x7d2a07f47be0>,
#  <__main__.Point at 0x7d2a07f47b80>,
#  <__main__.Point at 0x7d2a07f47b20>,
#  <__main__.Point at 0x7d2a07f47ac0>,
#  <__main__.Point at 0x7d2a07f47a60>,
#  <__main__.Point at 0x7d2a07f47a00>,
#  <__main__.Point at 0x7d2a07f479a0>,
#  <__main__.Point at 0x7d2a07f47940>,
#  <__main__.Point at 0x7d2a07f478e0>,
#  <__main__.Point at 0x7d2a07f47730>,
#  <__main__.Point at 0x7d2a07f476d0>,
#  <__main__.Point at 0x7d2a07f47670>,
#  <__main__.Point at 0x7d2a07f47610>,
#  <__main__.Point at 0x7d2a07f475b0>,
#  <__main__.Point at 0x7d2a07f47550>,
#  <__main__.Point at 0x7d2a07f474f0>,
#  <__main__.Point at 0x7d2a07f47490>,
#  <__main__.Point at 0x7d2a07f473a0>,
#  <__main__.Point at 0x7d2a07f47340>,
#  <__main__.Point at 0x7d2a07f472e0>,
#  <__main__.Point at 0x7d2a07f47280>,
#  <__main__.Point at 0x7d2a07f471f0>,
#  <__main__.Point at 0x7d2a07f47190>,
#  <__main__.Point at 0x7d2a07f47100>,
#  <__main__.Point at 0x7d2a07f46fe0>,
#  <__main__.Point at 0x7d2a0c0bc040>,
#  <__main__.Point at 0x7d2a0c0bc0a0>,
#  <__main__.Point at 0x7d2a0c0bc100>,
#  <__main__.Point at 0x7d2a0c0bc160>,
#  <__main__.Point at 0x7d2a0c0bc1c0>,
#  <__main__.Point at 0x7d2a0c0bc220>,
#  <__main__.Point at 0x7d2a0c0bc280>,
#  <__main__.Point at 0x7d2a0c0bc2e0>,
#  <__main__.Point at 0x7d2a0c0bc340>,
#  <__main__.Point at 0x7d2a0c0bc3a0>,
#  <__main__.Point at 0x7d2a0c0bc400>,
#  <__main__.Point at 0x7d2a0c0bc460>,
#  <__main__.Point at 0x7d2a0c0bc4c0>,
#  <__main__.Point at 0x7d2a0c0bc520>,
#  <__main__.Point at 0x7d2a0c0bc580>,
#  <__main__.Point at 0x7d2a0c0bc5e0>,
#  <__main__.Point at 0x7d2a0c0bc640>,
#  <__main__.Point at 0x7d2a0c0bc6a0>,
#  <__main__.Point at 0x7d2a0c0bc700>,
#  <__main__.Point at 0x7d2a0c0bc760>,
#  <__main__.Point at 0x7d2a0c0bc7c0>,
#  <__main__.Point at 0x7d2a0c0bc820>,
#  <__main__.Point at 0x7d2a0c0bc880>,
#  <__main__.Point at 0x7d2a0c0bc8e0>,
#  <__main__.Point at 0x7d2a0c0bc940>,
#  <__main__.Point at 0x7d2a0c0bc9a0>,
#  <__main__.Point at 0x7d2a0c0bca00>,
#  <__main__.Point at 0x7d2a0c0bca60>,
#  <__main__.Point at 0x7d2a0c0bd600>,
#  <__main__.Point at 0x7d2a0c0bd660>,
#  <__main__.Point at 0x7d2a0c0bd6c0>,
#  <__main__.Point at 0x7d2a0c0bd720>,
#  <__main__.Point at 0x7d2a0c0bd780>,
#  <__main__.Point at 0x7d2a0c0bd7e0>,
#  <__main__.Point at 0x7d2a0c0bd840>,
#  <__main__.Point at 0x7d2a0c0bd8a0>,
#  <__main__.Point at 0x7d2a0c0bd900>,
#  <__main__.Point at 0x7d2a0c0bd960>,
#  <__main__.Point at 0x7d2a0c0bd9c0>,
#  <__main__.Point at 0x7d2a0c0bda20>,
#  <__main__.Point at 0x7d2a0c0bda80>,
#  <__main__.Point at 0x7d2a0c0bdae0>,
#  <__main__.Point at 0x7d2a0c0bdb40>,
#  <__main__.Point at 0x7d2a0c0bdba0>,
#  <__main__.Point at 0x7d2a0c0bdc00>,
#  <__main__.Point at 0x7d2a0c0bdc60>,
#  <__main__.Point at 0x7d2a0c0bdcc0>,
#  <__main__.Point at 0x7d2a0c0bdd20>,
#  <__main__.Point at 0x7d2a0c0bdd80>,
#  <__main__.Point at 0x7d2a0c0bdde0>,
#  <__main__.Point at 0x7d2a0c0bde40>,
#  <__main__.Point at 0x7d2a0c0bdea0>,
#  <__main__.Point at 0x7d2a0c0bdf00>,
#  <__main__.Point at 0x7d2a0c0bdf60>,
#  <__main__.Point at 0x7d2a0c0bdfc0>,
#  <__main__.Point at 0x7d2a0c0be020>,
#  <__main__.Point at 0x7d2a0c0be080>,
#  <__main__.Point at 0x7d2a0c0be0e0>,
#  <__main__.Point at 0x7d2a0c0be140>,
#  <__main__.Point at 0x7d2a0c0be1a0>,
#  <__main__.Point at 0x7d2a0c0be200>,
#  <__main__.Point at 0x7d2a0c0be260>,
#  <__main__.Point at 0x7d2a0c0be2c0>,
#  <__main__.Point at 0x7d2a0c0be320>,
#  <__main__.Point at 0x7d2a0c0be380>,
#  <__main__.Point at 0x7d2a0c0be3e0>,
#  <__main__.Point at 0x7d2a0c0be440>,
#  <__main__.Point at 0x7d2a0c0be4a0>,
#  <__main__.Point at 0x7d2a0c0be500>,
#  <__main__.Point at 0x7d2a0c0be560>,
#  <__main__.Point at 0x7d2a0c0be5c0>,
#  <__main__.Point at 0x7d2a0c0be620>,
#  <__main__.Point at 0x7d2a0c0be680>,
#  <__main__.Point at 0x7d2a0c0bffa0>,
#  <__main__.Point at 0x7d2a0c0bff40>,
#  <__main__.Point at 0x7d2a0c0bfee0>,
#  <__main__.Point at 0x7d2a0c0bfe80>,
#  <__main__.Point at 0x7d2a0c0bfe20>,
#  <__main__.Point at 0x7d2a0c0bfdc0>,
#  <__main__.Point at 0x7d2a0c0bfd60>,
#  <__main__.Point at 0x7d2a0c0bfd00>,
#  <__main__.Point at 0x7d2a0c0bfca0>,
#  <__main__.Point at 0x7d2a0c0bfc40>,
#  <__main__.Point at 0x7d2a0c0bfbe0>,
#  <__main__.Point at 0x7d2a0c0bfb80>,
#  <__main__.Point at 0x7d2a0c0bfb20>,
#  <__main__.Point at 0x7d2a0c0bfac0>,
#  <__main__.Point at 0x7d2a0c0bfa60>,
#  <__main__.Point at 0x7d2a0c0bfa00>,
#  <__main__.Point at 0x7d2a0c0bf9a0>,
#  <__main__.Point at 0x7d2a0c0bf940>,
#  <__main__.Point at 0x7d2a0c0bf8e0>,
#  <__main__.Point at 0x7d2a0c0bf880>,
#  <__main__.Point at 0x7d2a0c0bf820>,
#  <__main__.Point at 0x7d2a0c0bf7c0>,
#  <__main__.Point at 0x7d2a0c0bf760>,
#  <__main__.Point at 0x7d2a0c0bf700>,
#  <__main__.Point at 0x7d2a0c0bf6a0>,
#  <__main__.Point at 0x7d2a0c0bf640>,
#  <__main__.Point at 0x7d2a0c0bf5e0>,
#  <__main__.Point at 0x7d2a0c0bf580>,
#  <__main__.Point at 0x7d2a0c0bf520>,
#  <__main__.Point at 0x7d2a0c0bf4c0>,
#  <__main__.Point at 0x7d2a0c0bf460>,
#  <__main__.Point at 0x7d2a0c0bf400>,
#  <__main__.Point at 0x7d2a0c0bf3a0>,
#  <__main__.Point at 0x7d2a0c0bf340>,
#  <__main__.Point at 0x7d2a0c0bf2e0>,
#  <__main__.Point at 0x7d2a0c0bf280>,
#  <__main__.Point at 0x7d2a0c0bf220>,
#  <__main__.Point at 0x7d2a0c0bf1c0>,
#  <__main__.Point at 0x7d2a0c0bf160>,
#  <__main__.Point at 0x7d2a0c0bf100>,
#  <__main__.Point at 0x7d2a0c0bf0a0>,
#  <__main__.Point at 0x7d2a0c0bf040>,
#  <__main__.Point at 0x7d2a0c0befe0>,
#  <__main__.Point at 0x7d2a0c0bef50>,
#  <__main__.Point at 0x7d2a0c0beef0>,
#  <__main__.Point at 0x7d2a0c0bee60>,
#  <__main__.Point at 0x7d2a0c0bee00>,
#  <__main__.Point at 0x7d2a0c0beda0>,
#  <__main__.Point at 0x7d2a0c0bed40>,
#  <__main__.Point at 0x7d2a0c0bece0>,
#  <__main__.Point at 0x7d2a0c0bec80>,
#  <__main__.Point at 0x7d2a0c0bec20>,
#  <__main__.Point at 0x7d2a0c0bebc0>,
#  <__main__.Point at 0x7d2a0c0beb60>,
#  <__main__.Point at 0x7d2a0c0beb00>,
#  <__main__.Point at 0x7d2a0c0beaa0>,
#  <__main__.Point at 0x7d2a0c0bea40>,
#  <__main__.Point at 0x7d2a0c0be9e0>,
#  <__main__.Point at 0x7d2a0c0be980>,
#  <__main__.Point at 0x7d2a0c0be920>,
#  <__main__.Point at 0x7d2a0c0be8c0>,
#  <__main__.Point at 0x7d2a0c0be860>,
#  <__main__.Point at 0x7d2a0c0be800>,
#  <__main__.Point at 0x7d2a0c0be7a0>,
#  <__main__.Point at 0x7d2a0c0be740>,
#  <__main__.Point at 0x7d2a0c0be6e0>,
#  <__main__.Point at 0x7d2a0c0bd5d0>,
#  <__main__.Point at 0x7d2a0c0bd570>,
#  <__main__.Point at 0x7d2a0c0bd510>,
#  <__main__.Point at 0x7d2a0c0bd4b0>,
#  <__main__.Point at 0x7d2a0c0bd450>,
#  <__main__.Point at 0x7d2a0c0bd3f0>,
#  <__main__.Point at 0x7d2a0c0bd390>,
#  <__main__.Point at 0x7d2a0c0bd330>,
#  <__main__.Point at 0x7d2a0c0bd2d0>,
#  <__main__.Point at 0x7d2a0c0bd270>,
#  <__main__.Point at 0x7d2a0c0bd210>,
#  <__main__.Point at 0x7d2a0c0bd1b0>,
#  <__main__.Point at 0x7d2a0c0bd150>,
#  <__main__.Point at 0x7d2a0c0bd0f0>,
#  <__main__.Point at 0x7d2a0c0bd090>,
#  <__main__.Point at 0x7d2a0c0bd030>,
#  <__main__.Point at 0x7d2a0c0bcfd0>,
#  <__main__.Point at 0x7d2a0c0bcf70>,
#  <__main__.Point at 0x7d2a0c0bcf10>,
#  <__main__.Point at 0x7d2a0c0bceb0>,
#  <__main__.Point at 0x7d2a0c0bce50>,
#  <__main__.Point at 0x7d2a0c0bcdf0>,
#  <__main__.Point at 0x7d2a0c0bcd90>,
#  <__main__.Point at 0x7d2a0c0bcd30>,
#  <__main__.Point at 0x7d2a0c0bccd0>,
#  <__main__.Point at 0x7d2a0c0bcc70>,
#  <__main__.Point at 0x7d2a0c0bcc10>,
#  <__main__.Point at 0x7d2a0c0bcb80>,
#  <__main__.Point at 0x7d2a0c0bcb20>,
#  <__main__.Point at 0x7d2a0c0bcac0>,
#  <__main__.Point at 0x7d2a0c0df160>,
#  <__main__.Point at 0x7d2a0c0df100>,
#  <__main__.Point at 0x7d2a0c0df0a0>,
#  <__main__.Point at 0x7d2a0c0df040>,
#  <__main__.Point at 0x7d2a0c0defe0>,
#  <__main__.Point at 0x7d2a0c0def80>,
#  <__main__.Point at 0x7d2a0c0def20>,
#  <__main__.Point at 0x7d2a0c0deec0>,
#  <__main__.Point at 0x7d2a0c0dee60>,
#  <__main__.Point at 0x7d2a0c0dee00>,
#  <__main__.Point at 0x7d2a0c0deda0>,
#  <__main__.Point at 0x7d2a0c0ded40>,
#  <__main__.Point at 0x7d2a0c0dece0>,
#  <__main__.Point at 0x7d2a0c0dec80>,
#  <__main__.Point at 0x7d2a0c0dec20>,
#  <__main__.Point at 0x7d2a0c0debc0>,
#  <__main__.Point at 0x7d2a0c0deb60>,
#  <__main__.Point at 0x7d2a0c0deb00>,
#  <__main__.Point at 0x7d2a0c0deaa0>,
#  <__main__.Point at 0x7d2a0c0dea40>,
#  <__main__.Point at 0x7d2a0c0de9e0>,
#  <__main__.Point at 0x7d2a0c0de980>,
#  <__main__.Point at 0x7d2a0c0de920>,
#  <__main__.Point at 0x7d2a0c0de8c0>,
#  <__main__.Point at 0x7d2a0c0de860>,
#  <__main__.Point at 0x7d2a0c0de800>,
#  <__main__.Point at 0x7d2a0c0de7a0>,
#  <__main__.Point at 0x7d2a0c0de740>,
#  <__main__.Point at 0x7d2a0c0de6e0>,
#  <__main__.Point at 0x7d2a0c0de680>,
#  <__main__.Point at 0x7d2a0c0de620>,
#  <__main__.Point at 0x7d2a0c0de5c0>,
#  <__main__.Point at 0x7d2a0c0de560>,
#  <__main__.Point at 0x7d2a0c0de500>,
#  <__main__.Point at 0x7d2a0c0de4a0>,
#  <__main__.Point at 0x7d2a0c0de440>,
#  <__main__.Point at 0x7d2a0c0de3e0>,
#  <__main__.Point at 0x7d2a0c0ddf60>,
#  <__main__.Point at 0x7d2a0c0ddfc0>,
#  <__main__.Point at 0x7d2a0c0de020>,
#  <__main__.Point at 0x7d2a0c0de080>,
#  <__main__.Point at 0x7d2a0c0de0e0>,
#  <__main__.Point at 0x7d2a0c0de140>,
#  <__main__.Point at 0x7d2a0c0de1a0>,
#  <__main__.Point at 0x7d2a0c0de200>,
#  <__main__.Point at 0x7d2a0c0dfa60>,
#  <__main__.Point at 0x7d2a0c0dfac0>,
#  <__main__.Point at 0x7d2a0c0dfb20>,
#  <__main__.Point at 0x7d2a0c0dfb80>,
#  <__main__.Point at 0x7d2a0c0dfbe0>,
#  <__main__.Point at 0x7d2a0c0dfc40>,
#  <__main__.Point at 0x7d2a0c0dfca0>,
#  <__main__.Point at 0x7d2a0c0dfd60>,
#  <__main__.Point at 0x7d2a0c0dfdc0>,
#  <__main__.Point at 0x7d2a0c0dfe20>,
#  <__main__.Point at 0x7d2a0c0dfeb0>,
#  <__main__.Point at 0x7d2a0c0dff10>,
#  <__main__.Point at 0x7d2a0c0dff70>,
#  <__main__.Point at 0x7d2a0c0ddf00>,
#  <__main__.Point at 0x7d2a0c0ddea0>,
#  <__main__.Point at 0x7d2a0c0dde40>,
#  <__main__.Point at 0x7d2a0c0ddde0>,
#  <__main__.Point at 0x7d2a0c0ddd80>,
#  <__main__.Point at 0x7d2a0c0ddd20>,
#  <__main__.Point at 0x7d2a0c0ddcc0>,
#  <__main__.Point at 0x7d2a0c0ddc60>,
#  <__main__.Point at 0x7d2a0c0ddc00>,
#  <__main__.Point at 0x7d2a0c0ddba0>,
#  <__main__.Point at 0x7d2a0c0ddb40>,
#  <__main__.Point at 0x7d2a0c0ddae0>,
#  <__main__.Point at 0x7d2a0c0dc040>,
#  <__main__.Point at 0x7d2a0c0dc0a0>,
#  <__main__.Point at 0x7d2a0c0dc100>,
#  <__main__.Point at 0x7d2a0c0dc160>,
#  <__main__.Point at 0x7d2a0c0dc1c0>,
#  <__main__.Point at 0x7d2a0c0dc220>,
#  <__main__.Point at 0x7d2a0c0dc280>,
#  <__main__.Point at 0x7d2a0c0dc2e0>,
#  <__main__.Point at 0x7d2a0c0dc340>,
#  <__main__.Point at 0x7d2a0c0dc3a0>,
#  <__main__.Point at 0x7d2a0c0dc400>,
#  <__main__.Point at 0x7d2a0c0dc460>,
#  <__main__.Point at 0x7d2a0c0dc4c0>,
#  <__main__.Point at 0x7d2a0c0dc520>,
#  <__main__.Point at 0x7d2a0c0dc580>,
#  <__main__.Point at 0x7d2a0c0dc5e0>,
#  <__main__.Point at 0x7d2a0c0dc640>,
#  <__main__.Point at 0x7d2a0c0dc6a0>,
#  <__main__.Point at 0x7d2a0c0dc700>,
#  <__main__.Point at 0x7d2a0c0dc760>,
#  <__main__.Point at 0x7d2a0c0dc7c0>,
#  <__main__.Point at 0x7d2a0c0dc820>,
#  <__main__.Point at 0x7d2a0c0dc880>,
#  <__main__.Point at 0x7d2a0c0dc8e0>,
#  <__main__.Point at 0x7d2a0c0dc940>,
#  <__main__.Point at 0x7d2a0c0dc9a0>,
#  <__main__.Point at 0x7d2a0c0dca00>,
#  <__main__.Point at 0x7d2a0c0dca60>,
#  <__main__.Point at 0x7d2a0c0dcac0>,
#  <__main__.Point at 0x7d2a0c0dcb20>,
#  <__main__.Point at 0x7d2a0c0dcb80>,
#  <__main__.Point at 0x7d2a0c0dcbe0>,
#  <__main__.Point at 0x7d2a0c0dcc40>,
#  <__main__.Point at 0x7d2a0c0dcca0>,
#  <__main__.Point at 0x7d2a0c0dcd00>,
#  <__main__.Point at 0x7d2a0c0dcd60>,
#  <__main__.Point at 0x7d2a0c0dcdc0>,
#  <__main__.Point at 0x7d2a0c0dce20>,
#  <__main__.Point at 0x7d2a0c0dce80>,
#  <__main__.Point at 0x7d2a0c0dcee0>,
#  <__main__.Point at 0x7d2a0c0dcf40>,
#  <__main__.Point at 0x7d2a0c0dcfa0>,
#  <__main__.Point at 0x7d2a0c0dd000>,
#  <__main__.Point at 0x7d2a0c0dd060>,
#  <__main__.Point at 0x7d2a0c0dd0c0>,
#  <__main__.Point at 0x7d2a0c0dd120>,
#  <__main__.Point at 0x7d2a0c0dd180>,
#  <__main__.Point at 0x7d2a0c0dd1e0>,
#  <__main__.Point at 0x7d2a0c0dd240>,
#  <__main__.Point at 0x7d2a0c0dd2a0>,
#  <__main__.Point at 0x7d2a0c0dd300>,
#  <__main__.Point at 0x7d2a0c0dd360>,
#  <__main__.Point at 0x7d2a0c0dd3c0>,
#  <__main__.Point at 0x7d2a0c0dd420>,
#  <__main__.Point at 0x7d2a0c0dd480>,
#  <__main__.Point at 0x7d2a0c0dd4e0>,
#  <__main__.Point at 0x7d2a0c0dd540>,
#  <__main__.Point at 0x7d2a0c0dd5a0>,
#  <__main__.Point at 0x7d2a0c0dd600>,
#  <__main__.Point at 0x7d2a0c0dd660>,
#  <__main__.Point at 0x7d2a0c0dd6c0>,
#  <__main__.Point at 0x7d2a0c0dd720>,
#  <__main__.Point at 0x7d2a0c0dd780>,
#  <__main__.Point at 0x7d2a0c0dd7e0>,
#  <__main__.Point at 0x7d2a0c0dd840>,
#  <__main__.Point at 0x7d2a0c0dd8a0>,
#  <__main__.Point at 0x7d2a0c0dd900>,
#  <__main__.Point at 0x7d2a0c0dd960>,
#  <__main__.Point at 0x7d2a0c0dd9c0>,
#  <__main__.Point at 0x7d2a0c0dda20>,
#  <__main__.Point at 0x7d2a0c0dda80>,
#  <__main__.Point at 0x7d2a0c0de290>,
#  <__main__.Point at 0x7d2a0c0de2f0>,
#  <__main__.Point at 0x7d2a0c0de350>,
#  <__main__.Point at 0x7d2a0c0de3b0>,
#  <__main__.Point at 0x7d2a0c1226b0>,
#  <__main__.Point at 0x7d2a0c122710>,
#  <__main__.Point at 0x7d2a0c122860>,
#  <__main__.Point at 0x7d2a0c1228c0>,
#  <__main__.Point at 0x7d2a0c122920>,
#  <__main__.Point at 0x7d2a0c122980>,
#  <__main__.Point at 0x7d2a0c1229e0>,
#  <__main__.Point at 0x7d2a0c122a40>,
#  <__main__.Point at 0x7d2a0c122aa0>,
#  <__main__.Point at 0x7d2a0c122b00>,
#  <__main__.Point at 0x7d2a0c122cb0>,
#  <__main__.Point at 0x7d2a0c122d10>,
#  <__main__.Point at 0x7d2a0c122d70>,
#  <__main__.Point at 0x7d2a0c122dd0>,
#  <__main__.Point at 0x7d2a0c122e30>,
#  <__main__.Point at 0x7d2a0c122e90>,
#  <__main__.Point at 0x7d2a0c120700>,
#  <__main__.Point at 0x7d2a0c120760>,
#  <__main__.Point at 0x7d2a0c1208b0>,
#  <__main__.Point at 0x7d2a0c120910>,
#  <__main__.Point at 0x7d2a0c120670>,
#  <__main__.Point at 0x7d2a0c120610>,
#  <__main__.Point at 0x7d2a0c1205b0>,
#  <__main__.Point at 0x7d2a0c120550>,
#  <__main__.Point at 0x7d2a0c1204f0>,
#  <__main__.Point at 0x7d2a0c120490>,
#  <__main__.Point at 0x7d2a0c120430>,
#  <__main__.Point at 0x7d2a0c1203d0>,
#  <__main__.Point at 0x7d2a0c120370>,
#  <__main__.Point at 0x7d2a0c120310>,
#  <__main__.Point at 0x7d2a0c123580>,
#  <__main__.Point at 0x7d2a0c123280>,
#  <__main__.Point at 0x7d2a0c123220>,
#  <__main__.Point at 0x7d2a0c1231c0>,
#  <__main__.Point at 0x7d2a0c123160>,
#  <__main__.Point at 0x7d2a0c123100>,
#  <__main__.Point at 0x7d2a0c1230a0>,
#  <__main__.Point at 0x7d2a0c123040>,
#  <__main__.Point at 0x7d2a0c122fe0>,
#  <__main__.Point at 0x7d2a0c122f80>,
#  <__main__.Point at 0x7d2a0c122f20>,
#  <__main__.Point at 0x7d2a0c122ec0>,
#  <__main__.Point at 0x7d2a0c122590>,
#  <__main__.Point at 0x7d2a0c120940>,
#  <__main__.Point at 0x7d2a0c1209a0>,
#  <__main__.Point at 0x7d2a0c120a00>,
#  <__main__.Point at 0x7d2a0c120a60>,
#  <__main__.Point at 0x7d2a0c120ac0>,
#  <__main__.Point at 0x7d2a0c120b20>,
#  <__main__.Point at 0x7d2a0c120b80>,
#  <__main__.Point at 0x7d2a0c120be0>,
#  <__main__.Point at 0x7d2a0c120c40>,
#  <__main__.Point at 0x7d2a0c120ca0>,
#  <__main__.Point at 0x7d2a0c120d00>,
#  <__main__.Point at 0x7d2a0c120d60>,
#  <__main__.Point at 0x7d2a0c121f30>,
#  <__main__.Point at 0x7d2a0c122620>,
#  <__main__.Point at 0x7d2a0c122560>,
#  <__main__.Point at 0x7d2a0c122500>,
#  <__main__.Point at 0x7d2a0c122470>,
#  <__main__.Point at 0x7d2a0c122200>,
#  <__main__.Point at 0x7d2a0c123a90>,
#  <__main__.Point at 0x7d2a0c123af0>,
#  <__main__.Point at 0x7d2a0c123b50>,
#  <__main__.Point at 0x7d2a0c123bb0>,
#  <__main__.Point at 0x7d2a0c123c10>,
#  <__main__.Point at 0x7d2a0c123c70>,
#  <__main__.Point at 0x7d2a0c123cd0>,
#  <__main__.Point at 0x7d2a0c123d30>,
#  <__main__.Point at 0x7d2a0c123d90>,
#  <__main__.Point at 0x7d2a0c123df0>,
#  <__main__.Point at 0x7d2a0c123e50>,
#  <__main__.Point at 0x7d2a0c122110>,
#  <__main__.Point at 0x7d2a0c122170>,
#  <__main__.Point at 0x7d2a0c1223b0>,
#  <__main__.Point at 0x7d2a0c122380>,
#  <__main__.Point at 0x7d2a0c122b60>,
#  <__main__.Point at 0x7d2a0c122c80>,
#  <__main__.Point at 0x7d2a0c1232e0>,
#  <__main__.Point at 0x7d2a0c121660>,
#  <__main__.Point at 0x7d2a0c121600>,
#  <__main__.Point at 0x7d2a0c1211b0>,
#  <__main__.Point at 0x7d2a0c121150>,
#  <__main__.Point at 0x7d2a0c1210f0>,
#  <__main__.Point at 0x7d2a0c121090>,
#  <__main__.Point at 0x7d2a0c121030>,
#  <__main__.Point at 0x7d2a0c120fd0>,
#  <__main__.Point at 0x7d2a0c1216c0>,
#  <__main__.Point at 0x7d2a0c121720>,
#  <__main__.Point at 0x7d2a0c121780>,
#  <__main__.Point at 0x7d2a0c123fa0>,
#  <__main__.Point at 0x7d2a0c123f10>,
#  <__main__.Point at 0x7d2a0c123a30>,
#  <__main__.Point at 0x7d2a0c1239d0>,
#  <__main__.Point at 0x7d2a0c123970>,
#  <__main__.Point at 0x7d2a0c123910>,
#  <__main__.Point at 0x7d2a0c1238b0>,
#  <__main__.Point at 0x7d2a0c123850>,
#  <__main__.Point at 0x7d2a0c1237f0>,
#  <__main__.Point at 0x7d2a0c123790>,
#  <__main__.Point at 0x7d2a0c123730>,
#  <__main__.Point at 0x7d2a0c1236d0>,
#  <__main__.Point at 0x7d2a0c123670>,
#  <__main__.Point at 0x7d2a0c123610>,
#  <__main__.Point at 0x7d2a0c120fa0>,
#  <__main__.Point at 0x7d2a0c120f40>,
#  <__main__.Point at 0x7d2a0c120ee0>,
#  <__main__.Point at 0x7d2a0c120e80>,
#  <__main__.Point at 0x7d2a0c120e20>,
#  <__main__.Point at 0x7d2a0c120dc0>,
#  <__main__.Point at 0x7d2a0c1227d0>,
#  <__main__.Point at 0x7d2a0c1234c0>,
#  <__main__.Point at 0x7d2a0c1215d0>,
#  <__main__.Point at 0x7d2a0c121270>,
#  <__main__.Point at 0x7d2a0c121210>,
#  <__main__.Point at 0x7d2a0c1207f0>,
#  <__main__.Point at 0x7d2a0c120850>,
#  <__main__.Point at 0x7d2a0c123eb0>,
#  <__main__.Point at 0x7d2a0c120280>,
#  <__main__.Point at 0x7d2a0c120220>,
#  <__main__.Point at 0x7d2a0c1201c0>,
#  <__main__.Point at 0x7d2a0c1212d0>,
#  <__main__.Point at 0x7d2a0c121330>,
#  <__main__.Point at 0x7d2a0c121390>,
#  <__main__.Point at 0x7d2a0c1213f0>,
#  <__main__.Point at 0x7d2a0c121450>,
#  <__main__.Point at 0x7d2a0c1214b0>,
#  <__main__.Point at 0x7d2a0c121510>,
#  <__main__.Point at 0x7d2a0c121570>,
#  <__main__.Point at 0x7d2a0c123460>,
#  <__main__.Point at 0x7d2a0c123400>,
#  <__main__.Point at 0x7d2a0c1233a0>,
#  <__main__.Point at 0x7d2a0c123340>,
#  <__main__.Point at 0x7d2a0c122c50>,
#  <__main__.Point at 0x7d2a0c122bf0>,
#  <__main__.Point at 0x7d2a0c10b6d0>,
#  <__main__.Point at 0x7d2a0c10b580>,
#  <__main__.Point at 0x7d2a0c10b4c0>,
#  <__main__.Point at 0x7d2a0c10b460>,
#  <__main__.Point at 0x7d2a0c10b3a0>,
#  <__main__.Point at 0x7d2a0c10b340>,
#  <__main__.Point at 0x7d2a0c10b2e0>,
#  <__main__.Point at 0x7d2a0c10b280>,
#  <__main__.Point at 0x7d2a0c1084c0>,
#  <__main__.Point at 0x7d2a0c108460>,
#  <__main__.Point at 0x7d2a0c108400>,
#  <__main__.Point at 0x7d2a0c1083a0>,
#  <__main__.Point at 0x7d2a0c108340>,
#  <__main__.Point at 0x7d2a0c1082e0>,
#  <__main__.Point at 0x7d2a0c108280>,
#  <__main__.Point at 0x7d2a0c109150>,
#  <__main__.Point at 0x7d2a0c109300>,
#  <__main__.Point at 0x7d2a0c10a4a0>,
#  <__main__.Point at 0x7d2a0c10a500>,
#  <__main__.Point at 0x7d2a0c109cc0>,
#  <__main__.Point at 0x7d2a0c109d20>,
#  <__main__.Point at 0x7d2a0c109f00>,
#  <__main__.Point at 0x7d2a0c109f60>,
#  <__main__.Point at 0x7d2a0c10bfa0>,
#  <__main__.Point at 0x7d2a0c109ae0>,
#  <__main__.Point at 0x7d2a0c109a50>,
#  <__main__.Point at 0x7d2a0c1099f0>,
#  <__main__.Point at 0x7d2a0c109bd0>,
#  <__main__.Point at 0x7d2a0c10a350>,
#  <__main__.Point at 0x7d2a0c10a2f0>,
#  <__main__.Point at 0x7d2a0c10a290>,
#  <__main__.Point at 0x7d2a0c10a230>,
#  <__main__.Point at 0x7d2a0c109690>,
#  <__main__.Point at 0x7d2a0c109630>,
#  <__main__.Point at 0x7d2a0c1095d0>,
#  <__main__.Point at 0x7d2a0c109570>,
#  <__main__.Point at 0x7d2a0c10a6b0>,
#  <__main__.Point at 0x7d2a0c10a710>,
#  <__main__.Point at 0x7d2a0c10a770>,
#  <__main__.Point at 0x7d2a0c10a7d0>,
#  <__main__.Point at 0x7d2a0c10a830>,
#  <__main__.Point at 0x7d2a0c10a890>,
#  <__main__.Point at 0x7d2a0c10a8f0>,
#  <__main__.Point at 0x7d2a0c10a950>,
#  <__main__.Point at 0x7d2a0c10a9b0>,
#  <__main__.Point at 0x7d2a0c10aa10>,
#  <__main__.Point at 0x7d2a0c10aa70>,
#  <__main__.Point at 0x7d2a0c10aad0>,
#  <__main__.Point at 0x7d2a0c10ab30>,
#  <__main__.Point at 0x7d2a0c10ab90>,
#  <__main__.Point at 0x7d2a0c10abf0>,
#  <__main__.Point at 0x7d2a0c10ac50>,
#  <__main__.Point at 0x7d2a0c108b80>,
#  <__main__.Point at 0x7d2a0c108b20>,
#  <__main__.Point at 0x7d2a0c108ac0>,
#  <__main__.Point at 0x7d2a0c108a60>,
#  <__main__.Point at 0x7d2a0c108a00>,
#  <__main__.Point at 0x7d2a0c1089a0>,
#  <__main__.Point at 0x7d2a0c108940>,
#  <__main__.Point at 0x7d2a0c1088e0>,
#  <__main__.Point at 0x7d2a0c108880>,
#  <__main__.Point at 0x7d2a0c108820>,
#  <__main__.Point at 0x7d2a0c1087c0>,
#  <__main__.Point at 0x7d2a0c108760>,
#  <__main__.Point at 0x7d2a0c1080a0>,
#  <__main__.Point at 0x7d2a0c108040>,
#  <__main__.Point at 0x7d2a0c108d90>,
#  <__main__.Point at 0x7d2a0c108df0>,
#  <__main__.Point at 0x7d2a0c108e50>,
#  <__main__.Point at 0x7d2a0c108eb0>,
#  <__main__.Point at 0x7d2a0c108f10>,
#  <__main__.Point at 0x7d2a0c108f70>,
#  <__main__.Point at 0x7d2a0c108fd0>,
#  <__main__.Point at 0x7d2a0c109030>,
#  <__main__.Point at 0x7d2a0c109090>,
#  <__main__.Point at 0x7d2a0c1090f0>,
#  <__main__.Point at 0x7d2a0c109390>,
#  <__main__.Point at 0x7d2a0c1093f0>,
#  <__main__.Point at 0x7d2a0c109450>,
#  <__main__.Point at 0x7d2a0c1094b0>,
#  <__main__.Point at 0x7d2a0c109510>,
#  <__main__.Point at 0x7d2a0c10a3b0>,
#  <__main__.Point at 0x7d2a0c10a410>,
#  <__main__.Point at 0x7d2a0c10a470>,
#  <__main__.Point at 0x7d2a0c10a560>,
#  <__main__.Point at 0x7d2a0c10baf0>,
#  <__main__.Point at 0x7d2a0c109ed0>,
#  <__main__.Point at 0x7d2a0c109d50>,
#  <__main__.Point at 0x7d2a0c109c60>,
#  <__main__.Point at 0x7d2a0c10bca0>,
#  <__main__.Point at 0x7d2a0c109c00>,
#  <__main__.Point at 0x7d2a0c109c30>,
#  <__main__.Point at 0x7d2a0c108be0>,
#  <__main__.Point at 0x7d2a0c108c40>,
#  <__main__.Point at 0x7d2a0c108ca0>,
#  <__main__.Point at 0x7d2a0c108d00>,
#  <__main__.Point at 0x7d2a0c1099c0>,
#  <__main__.Point at 0x7d2a0c109960>,
#  <__main__.Point at 0x7d2a0c109900>,
#  <__main__.Point at 0x7d2a0c1098a0>,
#  <__main__.Point at 0x7d2a0c109810>,
#  <__main__.Point at 0x7d2a0c1097b0>,
#  <__main__.Point at 0x7d2a0c10a5f0>,
#  <__main__.Point at 0x7d2a0c10a650>,
#  <__main__.Point at 0x7d2a0c10b100>,
#  <__main__.Point at 0x7d2a0c10b160>,
#  <__main__.Point at 0x7d2a0c10b1c0>,
#  <__main__.Point at 0x7d2a0c10b220>,
#  <__main__.Point at 0x7d2a0c10b730>,
#  <__main__.Point at 0x7d2a0c10b790>,
#  <__main__.Point at 0x7d2a0c10b7f0>,
#  <__main__.Point at 0x7d2a0c10b850>,
#  <__main__.Point at 0x7d2a0c10b8b0>,
#  <__main__.Point at 0x7d2a0c10b910>,
#  <__main__.Point at 0x7d2a0c10b970>,
#  <__main__.Point at 0x7d2a0c10b9d0>,
#  <__main__.Point at 0x7d2a0c10ba30>,
#  <__main__.Point at 0x7d2a0c10ba90>,
#  <__main__.Point at 0x7d2a0c10b0a0>,
#  <__main__.Point at 0x7d2a0c10b040>,
#  <__main__.Point at 0x7d2a0c10afe0>,
#  <__main__.Point at 0x7d2a0c10af80>,
#  <__main__.Point at 0x7d2a0c10af20>,
#  <__main__.Point at 0x7d2a0c10aec0>,
#  <__main__.Point at 0x7d2a0c10ae60>,
#  <__main__.Point at 0x7d2a0c10ae00>,
#  <__main__.Point at 0x7d2a0c10ada0>,
#  <__main__.Point at 0x7d2a0c10ad40>,
#  <__main__.Point at 0x7d2a0c10ace0>,
#  <__main__.Point at 0x7d2a0c108100>,
#  <__main__.Point at 0x7d2a0c108160>,
#  <__main__.Point at 0x7d2a0c1081c0>,
#  <__main__.Point at 0x7d2a0c108220>,
#  <__main__.Point at 0x7d2a0c1085e0>,
#  <__main__.Point at 0x7d2a0c108640>,
#  <__main__.Point at 0x7d2a0c1086a0>,
#  <__main__.Point at 0x7d2a0c108700>,
#  <__main__.Point at 0x7d2a0c1096f0>,
#  <__main__.Point at 0x7d2a0c109750>,
#  <__main__.Point at 0x7d2a0c10a110>,
#  <__main__.Point at 0x7d2a0c10a170>,
#  <__main__.Point at 0x7d2a0c10a1d0>,
#  <__main__.Point at 0x7d2a0c1092a0>,
#  <__main__.Point at 0x7d2a0c109240>,
#  <__main__.Point at 0x7d2a0c1091e0>,
#  <__main__.Point at 0x7d2a0c109180>,
#  <__main__.Point at 0x7d2a0c108550>,
#  <__main__.Point at 0x7d2a0c1085b0>,
#  <__main__.Point at 0x7d2a0c10b430>,
#  <__main__.Point at 0x7d2a0c10b550>,
#  <__main__.Point at 0x7d2a0c109b40>,
#  <__main__.Point at 0x7d2a07ffd5d0>,
#  <__main__.Point at 0x7d2a07ffd570>,
#  <__main__.Point at 0x7d2a07ffd510>,
#  <__main__.Point at 0x7d2a07ffd4b0>,
#  <__main__.Point at 0x7d2a07ffd450>,
#  <__main__.Point at 0x7d2a07ffd3f0>,
#  <__main__.Point at 0x7d2a07ffd390>,
#  <__main__.Point at 0x7d2a07ffd330>,
#  <__main__.Point at 0x7d2a07ffd2d0>,
#  <__main__.Point at 0x7d2a07ffd270>,
#  <__main__.Point at 0x7d2a07ffd210>,
#  <__main__.Point at 0x7d2a07ffd1b0>,
#  <__main__.Point at 0x7d2a07ffd150>,
#  <__main__.Point at 0x7d2a07ffd0f0>,
#  <__main__.Point at 0x7d2a07ffd090>,
#  <__main__.Point at 0x7d2a07ffd030>,
#  <__main__.Point at 0x7d2a07ffcfd0>,
#  <__main__.Point at 0x7d2a07ffcf70>,
#  <__main__.Point at 0x7d2a07ffcf10>,
#  <__main__.Point at 0x7d2a07ffceb0>,
#  <__main__.Point at 0x7d2a07ffce50>,
#  <__main__.Point at 0x7d2a07ffcdf0>,
#  <__main__.Point at 0x7d2a07ffcd90>,
#  <__main__.Point at 0x7d2a07ffcd30>,
#  <__main__.Point at 0x7d2a07ffccd0>,
#  <__main__.Point at 0x7d2a07ffcc70>,
#  <__main__.Point at 0x7d2a07ffcc10>,
#  <__main__.Point at 0x7d2a07ffcbb0>,
#  <__main__.Point at 0x7d2a07ffcb50>,
#  <__main__.Point at 0x7d2a07ffcaf0>,
#  <__main__.Point at 0x7d2a07ffca90>,
#  <__main__.Point at 0x7d2a07ffca30>,
#  <__main__.Point at 0x7d2a07ffc9d0>,
#  <__main__.Point at 0x7d2a07ffc970>,
#  <__main__.Point at 0x7d2a07ffc910>,
#  <__main__.Point at 0x7d2a07ffc8b0>,
#  <__main__.Point at 0x7d2a07ffc850>,
#  <__main__.Point at 0x7d2a07ffc7f0>,
#  <__main__.Point at 0x7d2a07ffc790>,
#  <__main__.Point at 0x7d2a07ffc3a0>,
#  <__main__.Point at 0x7d2a07ffc340>,
#  <__main__.Point at 0x7d2a07ffc2e0>,
#  <__main__.Point at 0x7d2a07ffc280>,
#  <__main__.Point at 0x7d2a07ffc220>,
#  <__main__.Point at 0x7d2a07ffc1c0>,
#  <__main__.Point at 0x7d2a07ffc160>,
#  <__main__.Point at 0x7d2a07ffc100>,
#  <__main__.Point at 0x7d2a07ffc0a0>,
#  <__main__.Point at 0x7d2a07ffc040>,
#  <__main__.Point at 0x7d2a07fff880>,
#  <__main__.Point at 0x7d2a07fff8e0>,
#  <__main__.Point at 0x7d2a07fff940>,
#  <__main__.Point at 0x7d2a07fff9a0>,
#  <__main__.Point at 0x7d2a07ffffa0>,
#  <__main__.Point at 0x7d2a07ffe560>,
#  <__main__.Point at 0x7d2a07ffe5c0>,
#  <__main__.Point at 0x7d2a07ffe620>,
#  <__main__.Point at 0x7d2a07ffe680>,
#  <__main__.Point at 0x7d2a07ffe6e0>,
#  <__main__.Point at 0x7d2a07ffe740>,
#  <__main__.Point at 0x7d2a07ffe7a0>,
#  <__main__.Point at 0x7d2a07ffe800>,
#  <__main__.Point at 0x7d2a07ffe860>,
#  <__main__.Point at 0x7d2a07ffe8c0>,
#  <__main__.Point at 0x7d2a07ffe920>,
#  <__main__.Point at 0x7d2a07ffe980>,
#  <__main__.Point at 0x7d2a07ffec50>,
#  <__main__.Point at 0x7d2a07ffebf0>,
#  <__main__.Point at 0x7d2a07ffeb90>,
#  <__main__.Point at 0x7d2a07ffeb30>,
#  <__main__.Point at 0x7d2a07ffead0>,
#  <__main__.Point at 0x7d2a07ffea70>,
#  <__main__.Point at 0x7d2a07ffea10>,
#  <__main__.Point at 0x7d2a07ffe9b0>,
#  <__main__.Point at 0x7d2a07fffb20>,
#  <__main__.Point at 0x7d2a07fffac0>,
#  <__main__.Point at 0x7d2a07fffa60>,
#  <__main__.Point at 0x7d2a07fffa00>,
#  <__main__.Point at 0x7d2a07ffd600>,
#  <__main__.Point at 0x7d2a07ffd660>,
#  <__main__.Point at 0x7d2a07ffd6c0>,
#  <__main__.Point at 0x7d2a07ffd720>,
#  <__main__.Point at 0x7d2a07ffd780>,
#  <__main__.Point at 0x7d2a07ffd7e0>,
#  <__main__.Point at 0x7d2a07ffd840>,
#  <__main__.Point at 0x7d2a07ffdcf0>,
#  <__main__.Point at 0x7d2a07ffdd50>,
#  <__main__.Point at 0x7d2a07ffddb0>,
#  <__main__.Point at 0x7d2a07ffde10>,
#  <__main__.Point at 0x7d2a07ffde70>,
#  <__main__.Point at 0x7d2a07ffded0>,
#  <__main__.Point at 0x7d2a07ffdf30>,
#  <__main__.Point at 0x7d2a07ffe500>,
#  <__main__.Point at 0x7d2a07ffe4a0>,
#  <__main__.Point at 0x7d2a07ffe440>,
#  <__main__.Point at 0x7d2a07ffe3e0>,
#  <__main__.Point at 0x7d2a07ffe380>,
#  <__main__.Point at 0x7d2a07ffe320>,
#  <__main__.Point at 0x7d2a07ffe2c0>,
#  <__main__.Point at 0x7d2a07ffe260>,
#  <__main__.Point at 0x7d2a07ffe200>,
#  <__main__.Point at 0x7d2a07ffe1a0>,
#  <__main__.Point at 0x7d2a07ffe140>,
#  <__main__.Point at 0x7d2a07ffe0e0>,
#  <__main__.Point at 0x7d2a07ffe080>,
#  <__main__.Point at 0x7d2a07ffe020>,
#  <__main__.Point at 0x7d2a07ffdfc0>,
#  <__main__.Point at 0x7d2a07ffdf60>,
#  <__main__.Point at 0x7d2a07ffc700>,
#  <__main__.Point at 0x7d2a07ffc6a0>,
#  <__main__.Point at 0x7d2a07ffc640>,
#  <__main__.Point at 0x7d2a07ffc5e0>,
#  <__main__.Point at 0x7d2a07ffc580>,
#  <__main__.Point at 0x7d2a07ffc520>,
#  <__main__.Point at 0x7d2a07ffc4c0>,
#  <__main__.Point at 0x7d2a07ffc460>,
#  <__main__.Point at 0x7d2a07ffc400>,
#  <__main__.Point at 0x7d2a07ffff40>,
#  <__main__.Point at 0x7d2a07fffee0>,
#  <__main__.Point at 0x7d2a07fffe80>,
#  <__main__.Point at 0x7d2a07fffe20>,
#  <__main__.Point at 0x7d2a07fffdc0>,
#  <__main__.Point at 0x7d2a07fffd60>,
#  <__main__.Point at 0x7d2a07fffd00>,
#  <__main__.Point at 0x7d2a07fffca0>,
#  <__main__.Point at 0x7d2a07fffc40>,
#  <__main__.Point at 0x7d2a07fffbe0>,
#  <__main__.Point at 0x7d2a07fffb80>,
#  <__main__.Point at 0x7d2a07ffd8d0>,
#  <__main__.Point at 0x7d2a07ffd930>,
#  <__main__.Point at 0x7d2a07ffd990>,
#  <__main__.Point at 0x7d2a07ffd9f0>,
#  <__main__.Point at 0x7d2a07ffda50>,
#  <__main__.Point at 0x7d2a07ffdab0>,
#  <__main__.Point at 0x7d2a07ffdb10>,
#  <__main__.Point at 0x7d2a07ffdb70>,
#  <__main__.Point at 0x7d2a07ffdbd0>,
#  <__main__.Point at 0x7d2a07ffdc30>,
#  <__main__.Point at 0x7d2a07ffdc90>,
#  <__main__.Point at 0x7d2a07ffefb0>,
#  <__main__.Point at 0x7d2a07ffed10>,
#  <__main__.Point at 0x7d2a0c0e28f0>,
#  <__main__.Point at 0x7d2a0c0e2920>,
#  <__main__.Point at 0x7d2a0c0e3ac0>,
#  <__main__.Point at 0x7d2a0c0e2560>,
#  <__main__.Point at 0x7d2a0c0e2710>,
#  <__main__.Point at 0x7d2a0c0e2f50>,
#  <__main__.Point at 0x7d2a0c0e36d0>,
#  <__main__.Point at 0x7d2a0c0e3730>,
#  <__main__.Point at 0x7d2a0c0e3790>,
#  <__main__.Point at 0x7d2a0c0e3850>,
#  <__main__.Point at 0x7d2a0c0e3970>,
#  <__main__.Point at 0x7d2a0c0e3100>,
#  <__main__.Point at 0x7d2a0c0e2b30>,
#  <__main__.Point at 0x7d2a0c0e3a90>,
#  <__main__.Point at 0x7d2a0c0e2470>,
#  <__main__.Point at 0x7d2a0c0e2590>,
#  <__main__.Point at 0x7d2a0c0e25f0>,
#  <__main__.Point at 0x7d2a0c0e2650>,
#  <__main__.Point at 0x7d2a0c0e26b0>,
#  <__main__.Point at 0x7d2a0c0e2f80>,
#  <__main__.Point at 0x7d2a0c0e2fe0>,
#  <__main__.Point at 0x7d2a0c0e3040>,
#  <__main__.Point at 0x7d2a0c0e3400>,
#  <__main__.Point at 0x7d2a0c0e3460>,
#  <__main__.Point at 0x7d2a0c0e34c0>,
#  <__main__.Point at 0x7d2a0c0e3520>,
#  <__main__.Point at 0x7d2a0c0e3580>,
#  <__main__.Point at 0x7d2a0c0e37c0>,
#  <__main__.Point at 0x7d2a0c0e38b0>,
#  <__main__.Point at 0x7d2a0c0e3910>,
#  <__main__.Point at 0x7d2a0c0e2b90>,
#  <__main__.Point at 0x7d2a0c0e2bf0>,
#  <__main__.Point at 0x7d2a0c0e2c50>,
#  <__main__.Point at 0x7d2a0c0e2cb0>,
#  <__main__.Point at 0x7d2a0c0e2d10>,
#  <__main__.Point at 0x7d2a0c0e2830>,
#  <__main__.Point at 0x7d2a0c0e2890>,
#  <__main__.Point at 0x7d2a0c0e2800>,
#  <__main__.Point at 0x7d2a0c0e2ec0>,
#  <__main__.Point at 0x7d2a0c0e2e60>,
#  <__main__.Point at 0x7d2a0c0e2380>,
#  <__main__.Point at 0x7d2a0c0e2290>,
#  <__main__.Point at 0x7d2a0c0e2020>,
#  <__main__.Point at 0x7d2a0c112cb0>,
#  <__main__.Point at 0x7d2a0c112c50>,
#  <__main__.Point at 0x7d2a0c112bf0>,
#  <__main__.Point at 0x7d2a0c112b90>,
#  <__main__.Point at 0x7d2a0c112b30>,
#  <__main__.Point at 0x7d2a0c112ad0>,
#  <__main__.Point at 0x7d2a0c112fe0>,
#  <__main__.Point at 0x7d2a0c112f80>,
#  <__main__.Point at 0x7d2a0c112f20>,
#  <__main__.Point at 0x7d2a0c111fc0>,
#  <__main__.Point at 0x7d2a0c111f60>,
#  <__main__.Point at 0x7d2a0c111f00>,
#  <__main__.Point at 0x7d2a0c111ea0>,
#  <__main__.Point at 0x7d2a0c111e40>,
#  <__main__.Point at 0x7d2a0c111de0>,
#  <__main__.Point at 0x7d2a0c111d80>,
#  <__main__.Point at 0x7d2a0c111d20>,
#  <__main__.Point at 0x7d2a0c111cc0>,
#  <__main__.Point at 0x7d2a0c111c60>,
#  <__main__.Point at 0x7d2a0c111c00>,
#  <__main__.Point at 0x7d2a0c112020>,
#  <__main__.Point at 0x7d2a0c112080>,
#  <__main__.Point at 0x7d2a0c1120e0>,
#  <__main__.Point at 0x7d2a0c112170>,
#  <__main__.Point at 0x7d2a0c1121d0>,
#  <__main__.Point at 0x7d2a0c112230>,
#  <__main__.Point at 0x7d2a0c112290>,
#  <__main__.Point at 0x7d2a0c1122f0>,
#  <__main__.Point at 0x7d2a0c112350>,
#  <__main__.Point at 0x7d2a0c1123b0>,
#  <__main__.Point at 0x7d2a0c112410>,
#  <__main__.Point at 0x7d2a0c112470>,
#  <__main__.Point at 0x7d2a0c1124d0>,
#  <__main__.Point at 0x7d2a0c112530>,
#  <__main__.Point at 0x7d2a0c112590>,
#  <__main__.Point at 0x7d2a0c1125f0>,
#  <__main__.Point at 0x7d2a0c112650>,
#  <__main__.Point at 0x7d2a0c1126b0>,
#  <__main__.Point at 0x7d2a0c1139d0>,
#  <__main__.Point at 0x7d2a0c1136d0>,
#  <__main__.Point at 0x7d2a0c113760>,
#  <__main__.Point at 0x7d2a0c1137c0>,
#  <__main__.Point at 0x7d2a0c113820>,
#  <__main__.Point at 0x7d2a0c113880>,
#  <__main__.Point at 0x7d2a0c1138e0>,
#  <__main__.Point at 0x7d2a0c113940>,
#  <__main__.Point at 0x7d2a0c1139a0>,
#  <__main__.Point at 0x7d2a0c110a30>,
#  <__main__.Point at 0x7d2a0c112a70>,
#  <__main__.Point at 0x7d2a0c112a10>,
#  <__main__.Point at 0x7d2a0c1129b0>,
#  <__main__.Point at 0x7d2a0c112950>,
#  <__main__.Point at 0x7d2a0c1110c0>,
#  <__main__.Point at 0x7d2a0c111060>,
#  <__main__.Point at 0x7d2a0c111000>,
#  <__main__.Point at 0x7d2a0c110fa0>,
#  <__main__.Point at 0x7d2a0c110f40>,
#  <__main__.Point at 0x7d2a0c110ee0>,
#  <__main__.Point at 0x7d2a0c110e80>,
#  <__main__.Point at 0x7d2a0c110e20>,
#  <__main__.Point at 0x7d2a0c110dc0>,
#  <__main__.Point at 0x7d2a0c110d60>,
#  <__main__.Point at 0x7d2a0c110d00>,
#  <__main__.Point at 0x7d2a0c110ca0>,
#  <__main__.Point at 0x7d2a0c110c40>,
#  <__main__.Point at 0x7d2a0c110be0>,
#  <__main__.Point at 0x7d2a0c110b80>,
#  <__main__.Point at 0x7d2a0c110b20>,
#  <__main__.Point at 0x7d2a0c110ac0>,
#  <__main__.Point at 0x7d2a0c110a60>,
#  <__main__.Point at 0x7d2a0c110070>,
#  <__main__.Point at 0x7d2a0c1100d0>,
#  <__main__.Point at 0x7d2a0c110130>,
#  <__main__.Point at 0x7d2a0c110190>,
#  <__main__.Point at 0x7d2a0c1101f0>,
#  <__main__.Point at 0x7d2a0c110250>,
#  <__main__.Point at 0x7d2a0c1102b0>,
#  <__main__.Point at 0x7d2a0c110310>,
#  <__main__.Point at 0x7d2a0c110370>,
#  <__main__.Point at 0x7d2a0c1103d0>,
#  <__main__.Point at 0x7d2a0c110430>,
#  <__main__.Point at 0x7d2a0c110490>,
#  <__main__.Point at 0x7d2a0c1104f0>,
#  <__main__.Point at 0x7d2a0c110550>,
#  <__main__.Point at 0x7d2a0c1105b0>,
#  <__main__.Point at 0x7d2a0c110610>,
#  <__main__.Point at 0x7d2a0c110670>,
#  <__main__.Point at 0x7d2a0c1106d0>,
#  <__main__.Point at 0x7d2a0c110730>,
#  <__main__.Point at 0x7d2a0c110790>,
#  <__main__.Point at 0x7d2a0c1107f0>,
#  <__main__.Point at 0x7d2a0c110850>,
#  <__main__.Point at 0x7d2a0c1108b0>,
#  <__main__.Point at 0x7d2a0c110910>,
#  <__main__.Point at 0x7d2a0c110970>,
#  <__main__.Point at 0x7d2a0c1109d0>,
#  <__main__.Point at 0x7d2a0c111300>,
#  <__main__.Point at 0x7d2a0c111360>,
#  <__main__.Point at 0x7d2a0c1113c0>,
#  <__main__.Point at 0x7d2a0c111420>,
#  <__main__.Point at 0x7d2a0c111480>,
#  <__main__.Point at 0x7d2a0c1114e0>,
#  <__main__.Point at 0x7d2a0c111120>,
#  <__main__.Point at 0x7d2a0c111180>,
#  <__main__.Point at 0x7d2a0c1111e0>,
#  <__main__.Point at 0x7d2a0c111240>,
#  <__main__.Point at 0x7d2a0c1112a0>,
#  <__main__.Point at 0x7d2a0c1135e0>,
#  <__main__.Point at 0x7d2a0c113fd0>,
#  <__main__.Point at 0x7d2a0c113f70>,
#  <__main__.Point at 0x7d2a0c113f10>,
#  <__main__.Point at 0x7d2a0c113eb0>,
#  <__main__.Point at 0x7d2a0c113e50>,
#  <__main__.Point at 0x7d2a0c113df0>,
#  <__main__.Point at 0x7d2a0c113d90>,
#  <__main__.Point at 0x7d2a0c113d30>,
#  <__main__.Point at 0x7d2a0c111570>,
#  <__main__.Point at 0x7d2a0c1115d0>,
#  <__main__.Point at 0x7d2a0c111630>,
#  <__main__.Point at 0x7d2a0c111690>,
#  <__main__.Point at 0x7d2a0c1116f0>]

# %% [markdown]
# # Подвиг 4.

# %% [markdown]
# Объявите три класса геометрических фигур: Line, Rect, Ellipse. Должна быть возможность создавать объекты каждого класса следующими командами:
#
# g1 = Line(a, b, c, d)
# g2 = Rect(a, b, c, d)
# g3 = Ellipse(a, b, c, d)
# Здесь в качестве аргументов a, b, c, d передаются координаты верхнего правого и нижнего левого углов (произвольные числа). В каждом объекте координаты должны сохраняться в локальных свойствах sp (верхний правый угол) и ep (нижний левый) в виде кортежей (a, b) и (c, d) соответственно.
#
# Сформируйте 217 объектов этих классов: для каждого текущего объекта класс выбирается случайно (или Line, или Rect, или Ellipse). Координаты также генерируются случайным образом (числовые значения). Все объекты сохраните в списке elements.
#
# В списке elements обнулите координаты объектов только для класса Line.
#
# P.S. На экран в программе ничего выводить не нужно.

# %%
import random

class Line:
    def __init__(self, a, b, c, d):
        self.sp  = (a, b)
        self.ep = (c, d)

class Rect:
    def __init__(self, a, b, c, d):
        self.sp  = (a, b)
        self.ep = (c, d)

class Ellipse:
    def __init__(self, a, b, c, d):
        self.sp  = (a, b)
        self.ep = (c, d)

elements = []
for i in range(217):
    a, b, c, d = [random.randint(0, 10) for i in range(4)]
    obj = random.choice([Line(a,b,c,d), Rect(a,b,c,d), Ellipse(a,b,c,d)])
    elements.append(obj)
    
for obj in elements:
    if isinstance(obj, Line):
        setattr(obj, 'sp', (0, 0))
        obj.ep = (0, 0)

# %% [markdown]
# # Подвиг 5.

# %% [markdown]
# Объявите класс TriangleChecker, объекты которого можно было бы создавать командой:
#
# tr = TriangleChecker(a, b, c)
# Здесь a, b, c - длины сторон треугольника.
#
# В классе TriangleChecker необходимо объявить метод is_triangle(), который бы возвращал следующие коды:
#
# 1 - если хотя бы одна сторона не число (не float или int) или хотя бы одно число меньше или равно нулю;
# 2 - указанные числа a, b, c не могут являться длинами сторон треугольника;
# 3 - стороны a, b, c образуют треугольник.
#
# Проверку параметров a, b, c проводить именно в таком порядке.
#
# Прочитайте из входного потока строку, содержащую три числа, разделенных пробелами, командой:
#
# a, b, c = map(int, input().split())
# Затем, создайте объект tr класса TriangleChecker и передайте ему прочитанные значения a, b, c. Вызовите метод is_triangle() из объекта tr и выведите результат на экран (код, который она вернет).
#
# Sample Input:
#
# 3 4 5
# Sample Output:
#
# 3

# %%
class TriangleChecker:
    
    def __init__(self, a, b, c):
        self.a = a
        self.b = b
        self.c = c

    def is_triangle(self):
        if sum([type(x) in (int, float) for x in [self.a, self.b, self.c]])<3 or sum([x<=0 for x in [self.a, self.b, self.c]])>0:
            # return sum([type(x) in (int, float) for x in [self.a, self.b, self.c]]), sum([x<=0 for x in [self.a, self.b, self.c]])
            return 1
        elif (self.a+self.b)<=self.c or (self.a+self.c)<=self.b or (self.c+self.b)<=self.a:
            return 2
        else: 
            return 3

a, b, c = [1,2,3]
# a, b, c = map(int, input().split()) # эту строчку не менять
tr = TriangleChecker(a,b,c)
print(tr.is_triangle())
# Out:
# 2

# %% [markdown]
# # Подвиг 6.

# %% [markdown]
# Объявите класс Graph, объекты которого можно было бы создавать с помощью команды:
#
# gr_1 = Graph(data)
# где data - список из числовых данных (данные для графика). При создании каждого экземпляра класса должны формироваться следующие локальные свойства:
#
# data - ссылка на список из числовых данных (у каждого объекта должен быть свой список с данными, нужно создавать копию переданного списка);
# is_show - булево значение (True/False) для показа (True) и сокрытия (False) данных графика (по умолчанию True);
#
# В этом классе объявите следующие методы:
#
# set_data(self, data) - для передачи нового списка данных в текущий график;
# show_table(self) - для отображения данных в виде строки из списка чисел (числа следуют через пробел);
# show_graph(self) - для отображения данных в виде графика (метод выводит в консоль сообщение: "Графическое отображение данных: <строка из чисел следующих через пробел>");
# show_bar(self) - для отображения данных в виде столбчатой диаграммы (метод выводит в консоль сообщение: "Столбчатая диаграмма: <строка из чисел следующих через пробел>");
# set_show(self, fl_show) - метод для изменения локального свойства is_show на переданное значение fl_show.
#
# Если локальное свойство is_show равно False, то методы show_table(), show_graph() и show_bar() должны выводить сообщение:
#
# "Отображение данных закрыто"
#
# Прочитайте из входного потока числовые данные с помощью команды:
#
# data_graph = list(map(int, input().split()))
# Создайте объект gr класса Graph с набором прочитанных данных, вызовите метод show_bar(), затем метод set_show() со значением fl_show = False и вызовите метод show_table(). На экране должны отобразиться две соответствующие строки.
#
# Sample Input:
#
# 8 11 10 -32 0 7 18
# Sample Output:
#
# Столбчатая диаграмма: 8 11 10 -32 0 7 18
# Отображение данных закрыто

# %%
class Graph:
    def __init__(self, data: list, is_show: bool=True):
        self.data = data.copy()
        self.is_show = is_show
        
    def set_data(self, data):
        self.data = data.copy()
    
    def show_table(self):
        if not self.is_show:
            print('Отображение данных закрыто')
        else:
            print(' '.join([str(n) for n in self.data]))
    
    def show_graph(self):
        if not self.is_show:
            print('Отображение данных закрыто')
        else:
            print(f'Графическое отображение данных: {" ".join([str(n) for n in self.data])}')
    
    def show_bar(self):
        if not self.is_show:
            print('Отображение данных закрыто')
        else:
            print(f'Столбчатая диаграмма: {" ".join([str(n) for n in self.data])}')
            
    def set_show(self, fl_show):
        self.is_show = fl_show

data_graph = list(map(int, input().split()))
# data_graph = [3,5,4,2]

gr = Graph(data_graph)
gr.show_bar()
gr.set_show(fl_show=False)
gr.show_table()
# Out:
# Столбчатая диаграмма: 4 5 3 2
# Отображение данных закрыто

# %% [markdown]
# # Подвиг 7.

# %% [markdown]
# Объявите в программе следующие несколько классов:
#
# CPU - класс для описания процессоров;
# Memory - класс для описания памяти;
# MotherBoard - класс для описания материнских плат.
#
# Обеспечить возможность создания объектов каждого класса командами:
#
# cpu = CPU(наименование, тактовая частота)
# mem = Memory(наименование, размер памяти)
# mb = MotherBoard(наименование, процессор, память1, память2, ..., памятьN)
# Обратите внимание при создании объекта класса MotherBoard можно передавать несколько объектов класса Memory, максимум N - по числу слотов памяти на материнской плате (N = 4).
#
# Объекты классов должны иметь следующие локальные свойства:
#
# для класса CPU: name - наименование; fr - тактовая частота;
# для класса Memory: name - наименование; volume - объем памяти;
# для класса MotherBoard: name - наименование; cpu - ссылка на объект класса CPU; total_mem_slots = 4 - общее число слотов памяти (атрибут прописывается с этим значением и не меняется); mem_slots - список из объектов класса Memory (максимум total_mem_slots = 4 штук по максимальному числу слотов памяти).
#
# Класс MotherBoard должен иметь метод get_config(self) для возвращения текущей конфигурации компонентов на материнской плате в виде следующего списка из четырех строк:
#
# ['Материнская плата: <наименование>',
# 'Центральный процессор: <наименование>, <тактовая частота>',
# 'Слотов памяти: <общее число слотов памяти>',
# 'Память: <наименование_1> - <объем_1>; <наименование_2> - <объем_2>; ...; <наименование_N> - <объем_N>']
#
# Создайте объект mb класса MotherBoard с одним CPU (объект класса CPU) и двумя слотами памяти (объекты класса Memory).
#
# P.S. Отображать на экране ничего не нужно, только создать объект по указанным требованиям.

# %%
class CPU:
    def __init__(self, name, fr):
        self.name = name
        self.fr = fr
    
class Memory:
    def __init__(self, name, volume):
        self.name = name
        self.volume = volume
    
class MotherBoard:
    total_mem_slots = 4
    def __init__(self, name, cpu: CPU, *args):
        self.name = name
        self.cpu = cpu
        self.mem_slots = [item for item in args]
        
    def get_config(self):
        return [f'Материнская плата: {self.name}',
                f'Центральный процессор: {self.cpu.name}, {self.cpu.fr}',
                f'Слотов памяти: {MotherBoard.total_mem_slots}',
                f'Память: {"; ".join(item.name + " - " + str(item.volume) for item in self.mem_slots)}']
    
cpu = CPU('cp', 2.7)
m1 = Memory('me512', 512)
m2 = Memory('me1024', 1024)
mb = MotherBoard('mb_name', cpu, m1, m2)
mb.get_config()
# Out:
# ['Материнская плата: mb_name',
#  'Центральный процессор: cp, 2.7',
#  'Слотов памяти: 4',
#  'Память: me512 - 512; me1024 - 1024']

# %% [markdown]
# # Подвиг 8.

# %% [markdown]
# Объявите в программе класс Cart (корзина), объекты которого создаются командой:
#
# cart = Cart()
# Каждый объект класса Cart должен иметь локальное свойство goods - список объектов для покупки (объекты классов Table, TV, Notebook и Cup). Изначально этот список должен быть пустым.
#
# В классе Cart объявить методы:
#
# add(self, gd) - добавление в корзину товара, представленного объектом gd;
# remove(self, indx) - удаление из корзины товара по индексу indx;
# get_list(self) - получение из корзины товаров в виде списка из строк:
#
# ['<наименовние_1>: <цена_1>',
# '<наименовние_2>: <цена_2>',
# ...
# '<наименовние_N>: <цена_N>']
#
# Объявите в программе следующие классы для описания товаров:
#
# Table - столы;
# TV - телевизоры;
# Notebook - ноутбуки;
# Cup - кружки.
#
# Объекты этих классов должны создаваться командой:
#
# gd = ИмяКласса(name, price)
# Каждый объект классов товаров должен содержать локальные свойства:
#
# name - наименование;
# price - цена.
#
# Создайте в программе объект cart класса Cart. Добавьте в него два телевизора (TV), один стол (Table), два ноутбука (Notebook) и одну кружку (Cup). Названия и цены придумайте сами.
#
# P.S. Отображать на экране ничего не нужно, только создать объекты по указанным требованиям.

# %%
from typing import List, Union

class Table:
    def __init__(self, name, price):
        self.name = name
        self.price = price
    
class TV:
    def __init__(self, name, price):
        self.name = name
        self.price = price
        
class Notebook:
    def __init__(self, name, price):
        self.name = name
        self.price = price
        
class Cup:
    def __init__(self, name, price):
        self.name = name
        self.price = price

class Cart:
    def __init__(self, goods: List[Union[Table, TV, Notebook, Cup]] = []):
        self.goods = goods
        
    def add(self, gd):
        self.goods += gd
        
    def remove(self, indx):
        self.goods.pop(indx)
        
    def get_list(self):
        return [f'{item.name}: {item.price}' for item in self.goods]
        
cart = Cart()
cart.add([TV('tv1', 111), TV('tv2', 222), Table('t1', 333), Notebook('n1', 444), Notebook('n2', 555), Cup('c1', 666)])
# cart.get_list()
# cart.goods
# Out:
# [<__main__.TV at 0x7d2a061405e0>,
#  <__main__.TV at 0x7d2a0404f6d0>,
#  <__main__.Table at 0x7d2a0404f0d0>,
#  <__main__.Notebook at 0x7d2a0404ebc0>,
#  <__main__.Notebook at 0x7d2a0404fd30>,
#  <__main__.Cup at 0x7d2a0404e710>]

# %% [markdown]
# # Подвиг 9.

# %% [markdown]
# Вам необходимо реализовать односвязный список (не список языка Python, объекты в списке не хранить, а формировать связанную структуру, показанную на рисунке) из объектов класса ListObject:
#
# Для этого объявите в программе класс ListObject, объекты которого создаются командой:
#
# obj = ListObject(data)
# Каждый объект класса ListObject должен содержать локальные свойства:
#
# next_obj - ссылка на следующий присоединенный объект (если следующего объекта нет, то next_obj = None);
# data - данные объекта в виде строки.
#
# В самом классе ListObject должен быть объявлен метод:
#
# link(self, obj) - для присоединения объекта obj такого же класса к текущему объекту self (то есть, атрибут next_obj объекта self должен ссылаться на obj).
#
# Прочитайте список строк из входного потока командой:
#
# lst_in = list(map(str.strip, sys.stdin.readlines()))
# Затем сформируйте односвязный список, в объектах которых (в атрибуте data) хранятся строки из списка lst_in (первая строка в первом объекте, вторая - во втором и  т.д.). На первый добавленный объект класса ListObject должна ссылаться переменная head_obj.
#
# P.S. В программе что-либо выводить на экран не нужно.
#
# Sample Input:
#
# 1. Первые шаги в ООП
# 1.1 Как правильно проходить этот курс
# 1.2 Концепция ООП простыми словами
# 1.3 Классы и объекты. Атрибуты классов и объектов
# 1.4 Методы классов. Параметр self
# 1.5 Инициализатор init и финализатор del
# 1.6 Магический метод new. Пример паттерна Singleton
# 1.7 Методы класса (classmethod) и статические методы (staticmethod)
# Sample Output:

# %%
import sys

class ListObject:
    def __init__(self, data: str, next_obj=None):
        self.data=data
        self.next_obj = next_obj
        
    def link(self, obj):
        self.next_obj = obj
    
# lst_in = list(map(str.strip, sys.stdin.readlines()))
lst_in = ['1. Первые шаги в ООП',
          '1.1 Как правильно проходить этот курс',
          '1.2 Концепция ООП простыми словами',
          '1.3 Классы и объекты. Атрибуты классов и объектов',
          '1.4 Методы классов. Параметр self',
          '1.5 Инициализатор init и финализатор del',
          '1.6 Магический метод new. Пример паттерна Singleton',
          '1.7 Методы класса (classmethod) и статические методы (staticmethod)']

lst_data = []
for line in lst_in:
    obj = (ListObject(line))
    lst_data.append(obj)

for i in range(len(lst_data)-1):
    lst_data[i].link(lst_data[i+1])
    
head_obj = lst_data[0]

# %%
head_obj

# %%
lst_data
# Out:
# [<__main__.ListObject at 0x7d2a0404de70>,
#  <__main__.ListObject at 0x7d2a0404e440>,
#  <__main__.ListObject at 0x7d2a0404f760>,
#  <__main__.ListObject at 0x7d2a0404f2e0>,
#  <__main__.ListObject at 0x7d2a0404dfc0>,
#  <__main__.ListObject at 0x7d2a0404f220>,
#  <__main__.ListObject at 0x7d2a0404e7a0>,
#  <__main__.ListObject at 0x7d2a0404d510>]

# %%
lst_data[0]

# %%
lst_data[0].next_obj == lst_data[1]
# Out:
# True

# %%
lst_data[1].next_obj

# %%
lst_data[2]

# %% [markdown]
# # Большой подвиг 10.

# %% [markdown]
# Объявите два класса:
#
# Cell - для представления клетки игрового поля;
# GamePole - для управления игровым полем, размером N x N клеток.
#
# С помощью класса Cell предполагается создавать отдельные клетки командой:
#
# c1 = Cell(around_mines, mine)
# Здесь around_mines - число мин вокруг данной клетки поля; mine - булева величина (True/False), означающая наличие мины в текущей клетке. При этом, в каждом объекте класса Cell должны создаваться локальные свойства:
#
# around_mines - число мин вокруг клетки (начальное значение 0);
# mine - наличие/отсутствие мины в текущей клетке (True/False);
# fl_open - открыта/закрыта клетка - булево значение (True/False). Изначально все клетки закрыты (False).
#
# С помощью класса GamePole должна быть возможность создавать квадратное игровое поле с числом клеток N x N:
#
# pole_game = GamePole(N, M)
# Здесь N - размер поля; M - общее число мин на поле. При этом, каждая клетка представляется объектом класса Cell и все объекты хранятся в двумерном списке N x N элементов - локальном свойстве pole объекта класса GamePole.
#
# В классе GamePole должны быть также реализованы следующие методы:
#
# init() - инициализация поля с новой расстановкой M мин (случайным образом по игровому полю, разумеется каждая мина должна находиться в отдельной клетке).
# show() - отображение поля в консоли в виде таблицы чисел открытых клеток (если клетка не открыта, то отображается символ #; мина отображается символом *; между клетками при отображении ставить пробел).
#
# При создании экземпляра класса GamePole в его инициализаторе следует вызывать метод init() для первоначальной инициализации игрового поля.
#
# В классе GamePole могут быть и другие вспомогательные методы.
#
# Создайте экземпляр pole_game класса GamePole с размером поля N = 10 и числом мин M = 12.
#
# P.S. На экран в программе ничего выводить не нужно.

# %%
class Cell:
    def __init__(self, around_mines: int, mine: bool, fl_open: bool=False):
        self.around_mines = around_mines # число мин вокруг данной клетки поля;
        self.mine = mine # булева величина (True/False), означающая наличие мины в текущей клетке.
        self.fl_open = fl_open # открыта/закрыта клетка - булево значение (True/False). Изначально все клетки закрыты (False).

class GamePole:
    def __init__(self, N: int, M: int):
        self.N = N # размер поля
        self.M = M # общее число мин на поле
        self.init()
        
    def init(self):
        '''инициализация поля с новой расстановкой M мин (случайным образом по игровому полю, 
        разумеется каждая мина должна находиться в отдельной клетке).'''
        self.pole = matrix = [[Cell(0, 0, 1) for _ in range(self.N)] for _ in range(self.N)]
        mine_idx = random.sample(range(0, self.N**2), self.M)
        i = 0
        for line in self.pole:
            for item in line:
                if i in mine_idx:
                    item.mine = 1
                i += 1

    def show(self):
        '''отображение поля в консоли в виде таблицы чисел открытых клеток 
        (если клетка не открыта, то отображается символ #; 
        мина отображается символом *; между клетками при отображении ставить пробел).'''
        for line in self.pole:
            print(' '.join(["#" if not item.fl_open else "*" for item in line]))
        
pole_game = GamePole(10, 12)
# [[item.mine for item in line] for line in pole_game.pole]
# pole_game.show()
# Out:
# * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * *
