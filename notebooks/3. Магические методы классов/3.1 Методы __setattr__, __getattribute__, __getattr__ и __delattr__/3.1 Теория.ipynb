# %%
class Point():
    MIN_COORD = 0
    MAX_COORD = 100

    def __init__(self, x, y):
        self.x = x
        self.y = y

    def set_coord(self, x, y):
        self.x = x
        self.y = y

pt = Point(1,2)
pt.x
# Out:
# 1

# %%
pt.MAX_COORD
# Out:
# 100

# %% [markdown]
# Пространство атрибутов класса является общим для всех экземпляров.
# Обращатсья внутри методов напрямую к атрибутам класса нельзя, только через имя класса или self.

# %%
class Point():
    MIN_COORD = 0
    MAX_COORD = 100

    def __init__(self, x, y):
        self.x = x
        self.y = y

    def set_coord(self, x, y):
        self.x = x
        self.y = y

    def set_bound(self, left):
        self.MIN_COORD = left
#         так делать нельзя, так создается атрибут внутри экземпляра класса, а атрибут класса не изменяется
#         Правильней было бы использовать @classmethod

pt = Point(1, 2)
pt.set_bound(-100)
print(pt.__dict__)
print(Point.__dict__)
# Out:
# {'x': 1, 'y': 2, 'MIN_COORD': -100}
# {'__module__': '__main__', 'MIN_COORD': 0, 'MAX_COORD': 100, '__init__': <function Point.__init__ at 0x000002A45DB62E60>, 'set_coord': <function Point.set_coord at 0x000002A45DB629E0>, 'set_bound': <function Point.set_bound at 0x000002A45DB60C10>, '__dict__': <attribute '__dict__' of 'Point' objects>, '__weakref__': <attribute '__weakref__' of 'Point' objects>, '__doc__': None}
