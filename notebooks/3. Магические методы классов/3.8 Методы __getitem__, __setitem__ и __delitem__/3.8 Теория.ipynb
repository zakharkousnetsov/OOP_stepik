# %% [markdown]
# Урок в прозе: https://proproprogs.ru/python_oop/magicheskie-metody-getitem-setitem-delitem
#
# Телеграм-канал: https://t.me/python_selfedu

# %%
# Магические методы
# __getitem__(self, item) – получение значения по ключу item;
# __setitem__(self, key, value) - запись значения value по ключу key;
# __delitem__(self, key) - удаление элемента по ключу кеу.

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = list(marks)


s1 = Student('sss', [1,2,3,4,5])
s1.marks[0]
# А что если бы мы хотели обращаться к первой оценке вот так: s1[0] ??
# Out:
# 1

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = list(marks)

    def __getitem__(self, item):
        if 0 <= item <= len(self.marks):
            return self.marks[item]
        raise IndexError('неверный индекс')


s1 = Student('sss', [1,2,3,4,5])
s1[0]
s1[99]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 14
#      12 s1 = Student('sss', [1,2,3,4,5])
#      13 s1[0]
# ---> 14 s1[99]
#
# Cell In[6], line 9, in Student.__getitem__(self, item)
#       7 if 0 <= item <= len(self.marks):
#       8     return self.marks[item]
# ----> 9 raise IndexError('неверный индекс')
#
# IndexError: неверный индекс

# %% [markdown]
# А что если через такой же синтаксис мы хотели бы менять оценки

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = list(marks)

    def __getitem__(self, item):
        if 0 <= item <= len(self.marks):
            return self.marks[item]
        raise IndexError('неверный индекс')

    def __setitem__(self, key, value):
        if (not isinstance(key, int)) or key < 0:
            raise TypeError('должен быть положительный инт')

        if key >= len(self.marks):
            # так мы можем расширить список
            off = key +1 - len(self.marks)
            self.marks.extend([None]*off)
        self.marks[key] = value


    def __delitem__(self, key):
        if (not isinstance(key, int)) or key < 0:
            raise TypeError('должен быть положительный инт')

        del self.marks[key]


s1 = Student('sss', [1,2,3,4,5])
s1[0] = 11
s1[10] = 123
print(s1.marks)
del s1[1]
print(s1.marks)
# Out:
# [11, 2, 3, 4, 5, None, None, None, None, None, 123]
# [11, 3, 4, 5, None, None, None, None, None, 123]
