# %% [markdown]
# Урок в прозе: https://proproprogs.ru/python_oop/python-instrukciya-raise-i-polzovatelskie-isklyucheniya
#
# Телеграм-канал: https://t.me/python_selfedu

# %% [markdown]
# Во всех прошлых примерах исключения возникали в случае каких-то ошибок

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
raise ZeroDivisionError('division by zero')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 raise ZeroDivisionError('division by zero')
#
# ZeroDivisionError: division by zero

# %% [markdown]
# короче после raise можно вызывать собственные пользовательские исключения

# %%
class PrintData:
    def print(self, data):
        self.send_data(data)
        print(f"печать: {str(data)}")

    def send_data(self, data):
        if not self.send_to_print(data):
            raise Exception("принтер не отвечает")

    def send_to_print(self, data):
        return False

p = PrintData()
p.print('dfdf')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 14
#      11         return False
#      13 p = PrintData()
# ---> 14 p.print('dfdf')
#
# Cell In[6], line 3, in PrintData.print(self, data)
#       2 def print(self, data):
# ----> 3     self.send_data(data)
#       4     print(f"печать: {str(data)}")
#
# Cell In[6], line 8, in PrintData.send_data(self, data)
#       6 def send_data(self, data):
#       7     if not self.send_to_print(data):
# ----> 8         raise Exception("принтер не отвечает")
#
# Exception: принтер не отвечает

# %%
try:
    p.print('dfdfd')
except Exception:
    print('сработало исключение')
# Out:
# сработало исключение

# %%
class ExceptionPrintSendData(Exception):
    def __init__(self, *args):
        self.message = args[0] if args else None

    def __str__(self):
        return f'ошибка: {self.message}'



class PrintData:
    def print(self, data):
        self.send_data(data)
        print(f"печать: {str(data)}")

    def send_data(self, data):
        if not self.send_to_print(data):
            raise ExceptionPrintSendData("принтер не отвечает")

    def send_to_print(self, data):
        return False

p = PrintData()
p.print('dfdf')
# Out:
# ---------------------------------------------------------------------------
# ExceptionPrintSendData                    Traceback (most recent call last)
# Cell In[10], line 23
#      20         return False
#      22 p = PrintData()
# ---> 23 p.print('dfdf')
#
# Cell In[10], line 12, in PrintData.print(self, data)
#      11 def print(self, data):
# ---> 12     self.send_data(data)
#      13     print(f"печать: {str(data)}")
#
# Cell In[10], line 17, in PrintData.send_data(self, data)
#      15 def send_data(self, data):
#      16     if not self.send_to_print(data):
# ---> 17         raise ExceptionPrintSendData("принтер не отвечает")
#
# ExceptionPrintSendData: ошибка: принтер не отвечает
