# %%
class Tutorial:
    title='title'                  # АТРИБУТ КЛАССА
    second_title = 'second_title'  # АТРИБУТ КЛАССА

    def __init__(self, name):
        self.name = name           # ЛОКАЛЬНЫЙ АТРИБУТ

# %%
2
# Out:
# 2

# %%
# !pip -V
# Out:
# pip 25.0 from C:\Users\z.kuznetsov\rds_repositories\OOP_stepik\myenv\Lib\site-packages\pip (python 3.11)
